# %% [markdown]
# # CSCI632 Homework 3: Probability
#
# ### Instructions
# This assignment is designed to cover key probability concepts used throughout *Deep Learning* (Goodfellow et al., Ch. 3).
# Show all steps and justify each answer.   You do not need to use LaTeX for these answers.
#
#
# ## Deliverables
# - A jupyter notebook, scanned image, or PDF of your typed, LaTeX, or handwritten solutions.
# - For conceptual questions, write concise but clear explanations.
# - For computational problems, show all steps.

# %% [markdown]
# NOTE: it is okay to omit $\cap$ symbol when denoting the event "$A$ and $B$" occur.
# Thus $P(A \cap B) = P(AB)$.  Which one we use is a matter of taste.

# %% [markdown]
# ### Part A. Venn diagram problems — draw and reason
#
# For each problem below, draw a Venn diagram (label all regions) and answer the questions.
# Show any probability calculations and briefly justify your conclusion about
# independence / disjointness / subset relationships.
#
# ---
#
# **Problem 1**. Two events with partial overlap
#
# Given: $P(A) = 0.4, P(B) = 0.5, P(A \cap B) = 0.2.$
#
# (a) Draw the Venn diagram and label the three regions ($A$, $B$, $A \cap B$).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     (b) Compute P(A|B) and P(B|A).

# %% [markdown]
# **Answer:**
#
# $$P(A\cap B) = 0.2 = P(A|B) P(B)$$
#
# $$P(A|B) = \frac{0.2}{0.5} = 0.4$$
# $$P(B|A) = \frac{0.2}{0.4} = 0.5$$

# %% [markdown]
#     (c) Are A and B independent? Are they disjoint?

# %% [markdown]
# **Answer:**
#
# They overlap and thus cannot be disjoint.
#
# A and B are independent only if $P(A\cap B) = P(A)P(B)$.
#
# $P(A)P(B) = 0.5 \cdot 0.4 = 0.2 = P(A \cap B)$
#
# Thus, A and B are independent.

# %% [markdown]
# ---
# **Problem 2**. Two events that are disjoint
#     - Given: $P(A) = 0.3, P(B) = 0.6, P(A \cap B) = 0.$
#
#     (a) Draw a Venn diagram consistent with these probabilities and label all regions.

# %% [markdown]
# **Answer:**
#
# ![image.png](attachment:image.png)
#
# Shows two ellipses with no overlap.

# %% [markdown]
#     (b) Are A and B independent? Explain why disjointness implies or does not imply independence.

# %% [markdown]
# **Answer:**
#
# $A$ and $B$ are disjoint.  This means $A$ and $B$ cannot appear at the same time. If one blocks the other and vice versa then they cannot be independent.

# %% [markdown]
# ---
# **Problem 3.** Two events with overlap
#
# Given: Sets $A$ and $B$ ovelap, $P(A) = 0.5, P(B) = 0.4, P(A \cap B) = 0.3$
#
# (a) Draw a Venn diagram consistent with these probability and label all regions.

# %% [markdown]
# **Answer 3(a)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (b) Are A and B independent?  Why?

# %% [markdown]
# **Answer:**
#
# $A$ and $B$ are independent only if $P(AB) = P(A)P(B)$.
#
# $$P(AB) = 0.3$$
#
# $$P(A)P(B) = 0.5 \cdot 0.4 = 0.2 \neq 0.3$$
#
# They are not independent.

# %% [markdown]
# ---
# **Problem 4.** Subset and overlapping events (three sets)
#
# Given three events $A, B, C$ with: $A \subset C$, $B$ overlaps $C$
# but is not a subset, and $A$ and $B$ are disjoint.
#
# $$P(A) = 0.2, P(B) = 0.3, P(C) = 0.6, P(B \cap C) = 0.1, A \cap B = 0$$
#
# (a) Draw a three-set Venn diagram consistent with these relations and label all regions.

# %% [markdown]
# **Possible Answer:**
#
# There are many ways we could create a Venn diagram that adheres to the relations
# as presented.
#
# I started with a $5" \times 5"$ box to represent the sample space $\Omega$.
#
# $A$ thus must have area	$5" \times 5" \times 0.2 = 5 \text{ sq. in}$.
# Let $A have width 2.5" and height 2".
#
# $B$ thus must have area $5" \times 5" \times 0.3 = 7.5 \text{ sq. in}$.
# Let $B$ have width 2.5" and height 3".
#
# $C$ thus must have area $5" \times 5" \times 0.6 = 15 \text{ sq. in}$.
# Let C has width 3" and height 5".
#
# $A \subset C$ so $A$ is placed entirely within $C$.
#
# $A$ and $B$ must be disjoint.
#
# $B$ and $C$ should overlap such that $P(B\cap C)=0.1$.
#
# $B$ has a height of 3" so we want $B$ to cover $C$ just enough that
# $3 \times$ height of $B$ equals $0.1 \times$ the area of $\Omega$.
# In other words,
#
# $h \times overlap = 25 \text{ sq. in.} \times 0.1 = 2.5 \text{ sq. in.}$
#
# $overlap = \frac{2.5"}{h}= \frac{2.5"}{3} = 0.8333333333".$
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# (b) Compute $P(A \cup B \cup C)$.
#
# **Answer:**
#
# $A$ is in $C$ so we must subtract that overlap once to ensure it is not double counted.
#
# $C$ overlaps so we must subtract the overlap once to ensure it is not double counted.
#
# $P(A \cup B \cup C) = P(A) + P(B) + P(C) - P(A \cap C) - P(B \cap C) + P(A \cap B \cap C)$
#
#  $P(A \cup B \cup C) = 0.2 + 0.3 + 0.6 - 0.2 - 0.1 + 0 = 0.8.$

# %% [markdown]
# (c) Is any pair independent? Which pairs? Why?
#
# **Answer:**
#
# $A$ and $B$ are jisjoint so, $P(AB) = 0$ while $P(A)P(B) = 0.2 \cdot 0.3 = 0.06$.  They are not independent.
# Disjoint events with $P > 0$ are always dependent.
#
# $A$ is within $C$ so $P(AC) = P(A) = 0.2, but $P(A)P(C) = 0.2 \cdot 0.6 = 0.12$.  They are not independent.
#
# $B$ and $C$ overlap, but $P(BC) = 0.1$ while $P(B)P(C) = 0.3 \cdot 0.6 = 0.18$. They are not independent.
#
# No pairs are independent.

# %% [markdown]
# ---
# **Problem 5.** Conditional independence scenario
#
# Setup: Describe events $A$ and $B$ that are not independent marginally
# but are independent conditional on event $C.$

# %% [markdown]
# "Marginally" in the above statement means to consider $A$ and $B$
# not conditioned on anything.
#
# (a) Sketch Venn diagrams for the joint distribution marginally
#     and the partition induced by $C$.
#
# **Answer:**
#
# $A$ and $B$ are not independent marginally means
# $P(A)P(B) \ne P(AB)$.
#
# I constructed an example as follows.
#
# I started with a $5" \times 5"$ square to represent the sample space $\Omega$,
# which thus has area 25 square inches.
#
# I divided the area as follows.  The 25 appearing in the denominators equals the area of $\Omega$.
#
# $$
# \begin{align*}
#   P(A)     &= \frac{1.5" \times 1.5"}{25 \text{ sq. in.}} = 0.09 \\
#   \\
#   P(B)     &= \frac{3" \times 3"}{25 \text{ sq. in.}} = 0.36 \\
#   \\
#   P(AB)    &= \frac{0.75" \times 0.75"}{25 \text{ sq. in.}} = 0.0225 \\
#   \\
#   P(A)P(B) &= 0.09 \times 0.36 = 0.0324
# \end{align*}
# $$
#
# $P(A)P(B) \neq P(AB)$ so $A$ and $B$ are not independent.
#
# For $A$ and $B$ to be independent conditional on event $C$ means
#
# $$P(A|C)P(B|C) = P(AB|C)$$
#
# $$
# \begin{align}
#   P(A|C)  &= \tfrac{1}{4} \\
#   P(B|C)  &= \tfrac{1}{4} \\
#   P(AB|C) &= \tfrac{1}{16}
# \end{align}
# $$
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#
# (b) Provide a small numeric example (choose probabilities) that
#     satisfies:
#
# **Answer:**
#
# $P(A \cap B) \ne P(A)P(B)$ but $P(A \cap B | C) = P(A|C)P(B|C)$.

# %% [markdown]
#
# (c) Explain why conditioning can create or remove independence.
#
# **Possible Answer**:
#
# The condition changes the environment.  For example, two symptoms may almost never appear
# together to such an extent that it appears one almost blocks the other.
# This could occur if the symptoms are caused by the same common factor but at
# different extrema.  For example, one occurs with low blood sugar and the
# other with high.
#
# However, a disease could weaken the body's ability to regulate itself causing them
# to now appear independently.
#
# This is an example where a common causal factor is removed (regulatory response).
#
# A similar situation could create dependence.  What if two symptoms can have
# a wide range of causes such that their appearance is independent when
# considered within the universe of everything that can happen.
#
# However, a particular disease may cause both symptoms to arise. This is an
# example of a common factor being introduced that causes two things to occur that usually
# occur independently.

# %% [markdown]
# ---
# **Problem 6.** From a standard 52-card deck,
#
# let $A$ = "card is red", $B$ = "card is a face card (J,Q,K)",
# $C$ = "card is a heart".
#
# (a) Draw Venn diagrams showing relationships between $A$, $B$, $C$ (treat sets as colors and ranks). Label regions with counts or probabilities.

# %% [markdown]
# **Possible Answer:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This shows counts for $A$, $B$, and $C$.  I could also include counts for
# $|A \cap B| = 6$, $|B \cap C| = 3$, $|A \cap C| = 13$, and
# $|A \cap B \cap C| = 3$.
#
# Or I could have used probabilities.
#
# $P(A) = \frac{26}{52} = \frac{1}{2}$
#
# $P(B) = \frac{12}{52} = \frac{3}{13}$
#
# $P(C) = \frac{13}{52} = \frac{1}{4}$
#
# $P(A \cap B) = \frac{6}{52} = \frac{3}{26}$
#
# $P(B \cap C) = \frac{3}{52}$
#
# $P(A \cap C) = \frac{13}{52} = \frac{1}{4}$
#
# $P(A \cap B \cap C) = \frac{3}{52}$

# %% [markdown]
# (b) State which events are disjoint, which are subsets, and whether any pairs are independent.

# %% [markdown]
# **Answer:**
#
# None of the sets are disjoint.
#
# $C$ is a subset of $A$.
#
# $A$ and $B$ are independent, because $P(A\cap B) = \tfrac{3}{26} = P(A)P(B)$
#
# $B$ and $C$ are independent, because $P(B\cap C) = \tfrac{3}{52} = P(B)P(C)$.
#
# $A$ and $C$ are dependent, because $P(A\cap C) = \tfrac{1}{4}$ while
# $P(A)P(C) = \tfrac12 \cdot \tfrac{1}{4} = \tfrac{1}{8}$, thus $P(A \cap C) \ne P(A) P(C)$.

# %% [markdown]
# ### Part B. Discrete Random Variables
#
# **Problem 7.** Basic conditional probability and independence
#   - Given events $A$ and $$B$ with $P(A) = 0.45, P(B) = 0.30,$ and $P(A \cap B) = 0.135$:
#
#   (a) Compute $P(A|B)$ and $P(B|A)$.
#
#   **Answer**
#
#   $$P(A|B) = \frac{P(AB)}{P(B)} = \frac{0.135}{0.3} = 0.45$$
#
#   $$P(B|A) = \frac{P(AB)}{P(A)} = \frac{0.135}{0.45} = 0.3$$
#
#   (b) Are A and B independent? Justify your answer.
#
#   **Answer**
#
#   $$P(A) P(B) = 0.45 \cdot 0.3 = 0.135 = P(AB)$$
#
#   $A$ and $B$ are independent because $P(AB) = P(A)P(B)$.

# %% [markdown]
# ----
# **Problem 8.** Bayes' rule — medical test example
#
#   - A disease has prevalence 1%. A diagnostic test has sensitivity 95% ($P(\text{ test+ } | \text{ disease })$)
#     and specificity 90% ($P(\text{ test- } | \text{ no disease )}$).
#
#     (a) Compute $P(\text{ disease } | \text{ test+ })$.
#
#     **Answer:**
#
#     From Bayes' Law
#
#     $$P(\text{ disease } | \text{ test+ })
#       = \frac{P(\text{test+ } | \text{ disease }) P(\text{ disease })}{P(\text{ test+ })} \tag{8.1}$$
#
#     where
#
#     $$P(\text{ test+ }) = P(\text{ test+ } | \text{ disease })P(\text{ disease })
#                         + P(\text{ test+ } | \text{ no disease })P(\text{ no disease }) \tag{8.2}$$
#
#     If the patient does not have the disease there are two possible outcomes:
#     a positive test or a negative test.  These are mutually exclusive and collectively
#     exhaustive so
#
#     $$P(\text{ test+ } | \text{ no disease }) + P(\text{ test- } | \text{ no disease }) = 1$$
#
#     which rearranges to
#
#     $$P(\text{ test+ } | \text{ no disease }) = 1 - P(\text{ test- } | \text{ no disease }). \tag{8.3}$$
#
#     Because a patient either has or does not have the disease and substituting (8.3) into (8.2), we get
#
#     $$P(\text{ test+ }) = P(\text{ test+ } | \text{ disease })P(\text{ disease })
#                         + (1 - P(\text{ test- } | \text{ no disease })) (1-P(\text{ disease })) \tag{8.5}$$
#
#     We are given the prevalence, sensitivity, and specificity so (8.5) becomes
#
#     $$P(\text{ test+ }) = 0.95 \cdot 0.01 + (1 - 0.9) \cdot (1 - 0.01) = 0.0095 + 0.099 = 0.1085 \tag{8.6}$$
#
#     Substituting (8.6) into (8.1) yields
#
#     $$P(\text{ disease } | \text{ test+ }) = \frac{0.95 \cdot 0.01}{0.1085} \approx \boxed{0.088}$$

# %% [markdown]
# (b) Compute $P(\text{ no disease } | \text{ test- })$.
#
# **Answer:**
#
# From Bayes' Law,
#
# $$P(\text{ no disease } | \text{ test- } )
#   = \frac{P( \text{ test- } | \text{ no disease } ) P( \text{ no disease })}{P(\text{ test- })} \tag{8.7}$$
#
# From the Law of Total Probability
#
# $$P(\text{ test- } ) = P(\text{ test- } | \text{ no disease }) P(\text{ no disease } )
#                      + P(\text{ test- } | \text{ disease } ) P( \text{ disease })
#                      = 0.9 \cdot 0.99 + (1-0.95) 0.01 = 0.8915 \tag{8.8}$$
#
# Substituting (8.8) into (8.7) yields
#
# $$P(\text{ no disease } | \text{ test- } ) = \frac{0.9 \cdot 0.99}{0.8915} \approx \boxed{0.9994}$$

# %% [markdown]
# (c) Explain how prevalence affects the posterior probability.
#
# **Answer:**
#
# $$\text{posterior probability} = \frac{\text{likelihood}}{\text{marginal probability}} \times \text{prior probability}$$
#
# In medicine, *prevalence* is the *prior probability* of a disease.  Meaning it is the probability
# of finding the disease in the population.
#
# The *sensitivity* of a test is the likelihood of obtaining a positive given the patient has the disease,
# i.e., $P( \text{ test+ } | {\text{ disease }})$.
#
# The posterior probability increases proportionally with the prior probability.

# %% [markdown]
# ---
# **Problem 9.** Chain rule and conditional probability with three events
#     - Let $A, B, C$ be events with
#     $$P(A) = 0.6, P(B | A) = 0.5, P(B | A^c) = 0.2,$$
#     $$P(C | A \cap B) = 0.9, P(C | A \cap B^c) = 0.4,$$
#     $$P(C | A^c \cap B) = 0.7, P(C | A^c \cap B^c) = 0.1.$$
#
# (a) Use the chain rule and total probability to compute $P(A \cap B \cap C)$.
#
# **Answer**
#
# $$P(A B C) = P(A) P(B|A) P(C | A B) = 0.6 \cdot 0.5 \cdot  0.9 = 0.27$$

# %% [markdown]
# (b) Compute $P(C)$ and $P(A | C)$.
#
# **Answer**
#
# From the law of total probability, we get
#
# $$P(C) = P(C A B) + P(C A B^c) + P(C A^c B) + P(C A^c B^c)  \tag{9.1}$$
#
# None of these components are given directly, but we can derive each.
#
# Applying the chain rule of probability to the first term in (9.1) we get
#
# $$P(C A B) = P(A) P(B|A) P(C | A B) = 0.6 \cdot 0.5 \cdot 0.9 = 0.27  \tag{9.2}$$
#
# This is what we derived in 9(a).

# %% [markdown]
# The second term in (9.1) by treating $A B^c$ as a single event, conditional
# probability yields
#
# $$P(C A B^c) = P(A B^c) P(C | A B^c)        \tag{9.3}$$
#
# $$P(AB) = P(A) P(B A)$$
#
# From Law of Total Probability,
#
# $$P(A B) + P(A B^c) = P(A)$$
#
# Rearranging
#
# $$P(A B^c) = P(A) - P(A B) = P(A) - P(A) P(B|A) = P(A)(1 - P(B|A))  \tag{9.4}$$
#
# Substituting (9.4) into (9.3) yields
#
# $$P(C A B^c) = P(A)(1 - P(B|A)) P(C | A B^c)$$
#
# All of the factors above are known, yielding
#
# $$P(C A B^c) = 0.6 (1 - 0.5) 0.4 = 0.12  \tag{9.5}$$

# %% [markdown]
# The third term in (9.1) is
#
# $$P(C A^c B) = P(A^c) P(B | A^c) P(C| A^c B) = (1 - P(A)) P(B|A^c) P(C | A^c B). \tag{9.6}$$
#
# All the factors in (9.6) are also known, so
#
# $$P(C A^c B) = (1 - 0.6) \cdot 0.2 \cdot 0.7 = 0.056. \tag{9.7}$$

# %% [markdown]
# The last term in (9.1) is
#
# $$P(C A^c B^c) = P(A^c B^c) P(C | A^c B^c) \tag{9.8}$$
#
# where
#
# $$P(A^c B^c) + P(A^c B) = P(A^c)$$
#
# $$P(A^c B^c) + P(B | A^c) P(A^c) = P(A^c)$$
#
# $$P(A^c B^c) = P(A^c) (1 - P(B | A^c)) = (1-P(A)) (1-P(B|A^c)) \tag{9.9}$$
#
# All of the factors in (9.9) are given
#
# $$P(A^c B^C) = (1-0.6)(1-0.2) = 0.32 \tag{9.10}$$
#
# Substituting (9.10) into (9.8) yields
#
# $$P(C A^c B^c) = 0.32 \cdot 0.1 = 0.032 \tag{9.11}$$
#
# Combining (9.2), (9.5), (9.7) and (9.11) yields
#
# $$P(C) = 0.27 + 0.12 + 0.056 + 0.032 = \boxed{0.478}$$

# %% [markdown]
# Now let's derive $P(A|C)$.
#
# $$P(A|C) P(C) = P(AC) \tag{9.12}$$
#
# From the 9(b), we know $P(A B C)$ and $P(A B^c C)$.
#
# $$P(AC) = P(A B C) + P(A B^c C) = 0.27 + 0.12 = 0.39. \tag{9.13}$$
#
# Substituting (9.13) into (9.12) yields
#
# $$P(A|C) = \frac{0.39}{0.478} \approx \boxed{0.816}$$

# %% [markdown]
# ---
# **Problem 10.** Draw a 5-card hand uniformly at random from a standard 52-card deck (without replacement).
#
#
# (a) Compute the probability the hand contains exactly two pairs (two distinct
#     ranks each appearing twice, plus a fifth card of a different rank). Give the
#     answer in terms of binomial coefficients (e.g., $n$ choose $k$).
#
#
# **Answer**:
#
# Choose two numbers or faces (ranks) to be the pairs.   Then choose two suits for
# each pair.  The remainnig card is any card from any suit so long as its face
# or number does not match either pair.
#
# $$P(\text{2 pairs}) = \frac{\binom{13}{2}\binom{4}{2}\binom{4}{2} \binom{4}{1} \cdot 11}{\binom{52}{5}} \approx \boxed{0.0475}$$
#
#
# (b) Compute the probability the hand contains at least one ace. Express
#     using complementary counting and combinatorial terms.
#
# **Answer**:
#
# $$P(\text{ at least 1 ace }) = 1 - P(\text{no aces}) = 1 - \frac{\binom{48}{5}}{\binom{52}{5}} \approx \boxed{0.341}$$

# %% [markdown]
# (c) Given the hand contains at least one ace, compute the conditional
#     probability that it contains exactly two aces.
#
# **Answer**:
#
# If it has one ace then there are 3 other aces in the deck.  We want the case
# when there are exactly 2.  This the probability of drawing exactly 1
# ace with 4 draws when 1 has been removed from the deck.
#
# I originally gave the answer below:
#
# $$P(\text{ exactly 2 aces | at least 1 ace }) = \frac{\binom{3}{1}\binom{48}{3}}{\binom{48}{4}} = \frac{12}{45} \approx \boxed{0.267}$$
#
# However, the denominator is missing certain cases.  Once we remove 1 ace, there are 51 cards remaining, not 48.
#
# $$P(\text{ exactly 2 aces | at least 1 ace }) = \frac{\binom{3}{1}\binom{48}{3}}{\binom{51}{4}}  \approx \boxed{0.207}$$

# %%
import random

# Function to simulate drawing 4 cards from a deck with 1 ace already in hand
def simulate_draws(num_simulations=20000):
    count_two_aces = 0

    for _ in range(num_simulations):
        # Create a deck with 51 cards (3 aces and 48 non-aces)
        deck = ['Ace'] * 3 + ['Non-Ace'] * 48
        random.shuffle(deck)

        # Draw 4 cards
        drawn_cards = random.sample(deck, 4)

        # Check if exactly 1 more ace is drawn (total 2 aces including the one in hand)
        if drawn_cards.count('Ace') == 1:
            count_two_aces += 1

    # Probability of having exactly 2 aces
    probability = count_two_aces / num_simulations
    return probability

# Run the simulation
probability_two_aces = simulate_draws()
print(f"Probability of having exactly 2 aces: {probability_two_aces:.4f}")
# Out:
# Probability of having exactly 2 aces: 0.2068

# %% [markdown]
# ---
# **Problem 11.** Probability Mass Functions (PMF)
#
# - Let $X$ be a discrete random variable with the following probability mass function (PMF):
#
# $$
# P(X = x) =
# \begin{cases}
# 0.1 & \text{if } x = 1, \\
# 0.2 & \text{if } x = 2, \\
# 0.3 & \text{if } x = 3, \\
# 0.4 & \text{if } x = 4, \\
# 0 & \text{otherwise.}
# \end{cases}
# $$
#
# (a) Verify that this is a valid PMF.
#
# **Answer:**
#
# A valid PMF has all nonnegative probability masses and these masses
# sum to 1.
#
# $0.1 + 0.2 + 0.3 + 0.4 = 1.0$
#
# QED

# %% [markdown]
# (b) Compute $P(X \leq 3)$.
#
# **Answer:**
#
# $P[X=3] = 0.3$

# %% [markdown]
# (c) Compute the expected value $\mathbb{E}[X]$.
#
# **Answer:**
#
# $$\sum_{x=1}^4 x P[X = x] = 1 \cdot 0.1 + 2 \cdot 0.2 + 3 \cdot 0.3 + 4 \cdot 0.4
#   = 0.1 + 0.4 + 0.9 + 1.6 = \boxed{3}$$

# %%
import numpy as np

outcomes = np.array([1, 2, 3, 4])
probs = np.array([0.1, 0.2, 0.3, 0.4])

mean = np.sum(outcomes * probs)
mean
# Out:
# 3.0

# %% [markdown]
# (d) Compute the variance $\text{Var}(X)$.
#
# **Answer:**
#
# \begin{align}
#   \text{Var}(X) &= \mathbb{E}[(X-\overline{X})^2] = \mathbb{E}[X^2] - \overline{X}^2 \\
#                 &= 1^2 \cdot 0.1 + 2^2 \cdot 0.2 + 3^2 \cdot 0.3 + 4^2 \cdot 0.4 - 3^2 \\
#                 &= 0.1 + 0.8 + 2.7 + 6.4 - 9 = \boxed{1}
# \end{align}

# %%
# Compute the expected value of X^2
expected_x_sq = np.sum(outcomes**2 * probs)

# Compute the variance
variance = expected_x_sq - mean**2
variance
# Out:
# 1.0

# %% [markdown]
# ### Part C. Continuous random variables — expectation and variance
#
# For each problem below, show all integration steps and justify any changes of variables. Compute the expectation $\mathbb{E}[X]$ and the variance $\mathrm{Var}(X)$.
#
# **Problem 12.** Let $X\sim\mathrm{Uniform}(a,b)$ with $-\infty<a<b<\infty$.
#
# **(a)** Write the pdf $f_X(x)$ and verify it integrates to $1$.

# %% [markdown]
# **Answer 12(a)**
#
# $$\int_a^b f_X(x) dx = \int_a^b \frac{1}{b-a} dx = \frac{1}{b-a} \cdot x \big|_a^b = 1.$$

# %% [markdown]
#  (b) Compute $\mathbb{E}[X]$ and $\mathrm{Var}(X)$ in terms of $a,b$.

# %% [markdown]
# $$\mathbb{E}[X] = \int_a^b x f_X(x)~dx = \frac12 x^2 \frac{1}{b-a} \bigg|_a^b = \boxed{\frac{a+b}{2}}$$
#
# \begin{align*}
#   \mathbb{Var}[X] &= \int_a^b x^2 f_X(x)~dx - \mu^2
#                   = \frac13 x^3 \frac{1}{b-a} \bigg|_a^b - \mu^2 \\
#                   \\
#                   &= \frac{b^3-a^3}{3(b-a)} - \frac{(a+b)^2}{4}
#                   = \frac{(b^2 + ab + a^2)(b-a)}{3(b-a)} - \frac{(a^2+2ab + b^2)}{4} \\
#                   \\
#                   &= \frac{4(b^2 + ab + a^2)}{12} - \frac{3(a^2+2ab + b^2)}{12} \\
#                   \\
#                   &= \boxed{\frac{(a-b)^2}{12}}
# \end{align*}

# %% [markdown]
# ---
# **Problem 13.** Let $X$ have pdf
#
# $$
# f_X(x)=
# \begin{cases}
#   kx^2, & 0\le x\le 1,\\[4pt]
#   0, & \text{otherwise.}
# \end{cases}
# $$

# %% [markdown]
# **(a)** Find the normalizing constant $k$.
#
# \begin{align*}
#   \int_0^1 k x^2 dx &=& 1 \\
#   \\
#   k \cdot \frac{1}{3} x^3 \bigg|_0^1 &=& 1 \\
#   \\
#   k &= \boxed{3}
# \end{align*}

# %% [markdown]
# **(b)** Compute $\mathbb{E}[X]$ and $\mathrm{Var}(X)$.
#
# $$\int_0^1 x \cdot 3x^2 dx = \frac{3}{4} x^4 \bigg|_0^1 = \boxed{\frac{3}{4}}$$

# %% [markdown]
# ---
# **Problem 14**. Let $X\sim\mathrm{Exponential}(\lambda)$ with $\lambda>0$, i.e. $f_X(x)=\lambda e^{-\lambda x}$ for $x\ge0$.
#     Compute $\mathbb{E}[X]$ and $\mathrm{Var}(X)$ (show the integrals).

# %% [markdown]
# Simply solved using integration by parts.
#
# \begin{align*}
#   \mathbb{E}[X] &= \int_0^\infty x \lambda e^{-\lambda x} dx, \\
#   u &= x, dv = \lambda e^{-\lambda x} dx \\
#   uv - \int v du &= - \lambda x e^{-\lambda x} +\int_0^\infty e^{-\lambda x} dx \\
#                  &= -x e^{-\lambda x} - \frac{1}{\lambda} e^{-\lambda x} \bigg|_0^\infty \\
#                  &= \boxed{\frac{1}{\lambda}}
# \end{align*}

# %% [markdown]
# We can solve for the variance by using integration by parts once and then
# reusing the solution above.
#
# \begin{align*}
#   \text{Var}[X] &= \int_0^\infty x^2 \lambda e^{-\lambda x} dx \\
#      &= -x^2 e^{-\lambda x}\Big|_0^\infty + \int_0^\infty 2x e^{-\lambda x} dx \\
#      &= \boxed{\frac{2}{\lambda^2}}
# \end{align*}

# %% [markdown]
# ### Part D. Functions often used in ML

# %% [markdown]
# ---
# **Problem 15**. Sigmoid Function
#
# The sigmoid function is often used in machine learning and statistics to model probabilities. It is defined as:
#
# $$
#   \sigma(x) = \frac{1}{1 + e^{-x}}
# $$
#
# (a) Compute the value of $\sigma(0)$ and interpret its meaning in terms of probability.
#
# **Answer 15(a)**
#
# $$\sigma(0) = \frac{1}{1 + e^0} = \frac12$$
#
# If this a CDF then it means that 1/2 of the probability is below zero and 1/2 above.
#
# Althought this detail is not required for this answer, sigmoids are often used
# as an activation function for a neural network node where values above 0 represent
# activation and below zero represents deactivation, but with a smooth transition
# so that the gradient is defined everywhere.

# %% [markdown]
# (b) Show that $\sigma(-x) = 1 - \sigma(x)$.
#
# **Answer 15(b)**
#
# \begin{align*}
#   \sigma(-x) &= \frac{1}{1+ e^{-(-x)}} \\
#              &= \frac{1}{1+e^x} \cdot \frac{e^{-x}}{e^{-x}} \\
#              &= \frac{e^{-x}}{1+e^{-x}} \\
#              &= \frac{1 - 1 + e^{-x}}{1+e^{-x}} \\
#              &= 1 - \frac{1}{1 + e^{-x}} \\
#              &= 1 - \sigma(x)
# \end{align*}

# %% [markdown]
# (c) Plot the sigmoid function for $x \in [-10, 10]$ and describe its key properties (e.g., range, asymptotes, etc.).
#
# **Answer 15(c)**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate values for x
x = np.linspace(-10, 10, 500)  # from -10 to 10 with 500 points
y = 1 / (1 + np.exp(-x))

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label="$\sigma(x)$", linewidth=2)

# Add labels and title
plt.title("Plot of $\sigma(x)$")
plt.xlabel("$x$ (radians)")
plt.ylabel("$\sigma(x)$")

# Add grid and legend
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/ps/l87rj9215hd5rjf5zqwjz04h0000gq/T/ipykernel_84051/972555641.py:10: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, y, label="$\sigma(x)$", linewidth=2)
# /var/folders/ps/l87rj9215hd5rjf5zqwjz04h0000gq/T/ipykernel_84051/972555641.py:13: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("Plot of $\sigma(x)$")
# /var/folders/ps/l87rj9215hd5rjf5zqwjz04h0000gq/T/ipykernel_84051/972555641.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("$\sigma(x)$")

# %% [markdown]
# Describe its key properties (e.g., range, asymptotes, etc.).
#
# Range is 0 to 1.
#
# Asymptotically becomes 1 as $x \rightarrow \infty$.
#
# Symmetric about $x=0$.

# %% [markdown]
# ---
# **Problem 16**. Hyperbolic Tangent Function
#
# The hyperbolic tangent function, $\tanh(x)$, is another function commonly used in
# machine learning. It is defined as:
#
# $$
#   \tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}
# $$
#
# (a) Compute the value of $\tanh(0)$.

# %% [markdown]
# **Answer 16(a)**
#
# $$\tanh(x) = \frac{e^0-e^0}{e^0 + e^0} = \frac{0}{2} = \boxed{0}$$

# %% [markdown]
# (b) Show that $\tanh(-x) = -\tanh(x)$.
#
# **Answer 16(b)**
#
# $$\tanh(-x)= \frac{e^{(-x)} - e^{-(-x)}}{e^{(-x)} + e^{-(-x)}} = - \frac{e^x - e^{-x}}{e^x + e^{-x}} = -\tanh(x)$$

# %% [markdown]
# (c) Plot the $\tanh(x)$ function for $x \in [-10, 10]$ and describe its key properties (e.g., range, asymptotes, symmetry, etc.).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate values for x
x = np.linspace(-10, 10, 500)  # from -10 to 10 with 500 points
y = np.tanh(x)

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label="tanh$(x)$", linewidth=2)

# Add labels and title
plt.title("Plot of tanh$(x)$")
plt.xlabel("$x$ (radians)")
plt.ylabel("tanh$(x)$")

# Add grid and legend
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# (d) Compare $\tanh(x)$ with the sigmoid function $\sigma(x)$ in terms of output range.

# %% [markdown]
# **Possible Answer 16(c)**
#
# The range of the sigmoid is from zero to 1.  The range of the tanh function is from -1 to 1.
#
# *Optional detail:* Although the following detail is not necessary to answer the question, a sigmoid can only represent
# an output in the range of zero to 1, but when the output is scaled by a constant it allows the
# sigmoid to represent any value in 0 to an arbitrarily high constant.  When a sigmoid is applied
# to the output of a linear combination as with linear regression, the output can be constrained
# to match only positive values.  Additionally it introduces a nonlinearity which as we will show
# later is necessary for building networks of neurons where neurons can be viewed as
# scaled switch that are either "on" or "off."
#
# A tanh importantly represent either positive or negative numbers, and although it is
# limited to -1 to 1, by multiplying by a constant we can represent arbitrarily large
# numbers anywhere in $\mathbb{R}$.   This allows our network to be trained to match
# both positive and negative values, e.g., as occurs in regression problems that are
# have both positive and negative observed values.
